# %%
import sys
import os

# Get the absolute path to the project directory
project_dir = os.path.abspath("..")

# Append the project directory to sys.path
if project_dir not in sys.path:
    sys.path.append(project_dir)

# %%
import polars as pl
from typing import Dict

from src.common.AssetData import AssetData
from src.common.AssetDataService import AssetDataService
from src.common.AssetFileInOut import AssetFileInOut 
from src.common.AssetDataPolars import AssetDataPolars 
from src.databaseService.EstablishStocks import EstablishStocks 
from src.databaseService.OutsourceLoader import OutsourceLoader
from src.databaseService.CleanData import CleanData

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\kimer\Desktop\RandomOdyssey\notebooks

# %%
assets=AssetFileInOut("../src/stockGroups/bin").loadDictFromFile("group_snp500_over20years")

# Convert to Polars for speedup
assetspl: Dict[str, AssetDataPolars] = {}
for ticker, asset in assets.items():
    assetspl[ticker]= AssetDataService.to_polars(asset)

# %%
aTick = assetspl["A"]
fin = aTick.financials_quarterly

aShareprice = aTick.shareprice

rows_with_nulls = aShareprice.filter(
    pl.any_horizontal(
        pl.all().is_null()
    )
)

print(rows_with_nulls)
# Out:
# shape: (0, 9)
# ┌──────┬──────┬──────┬─────┬───┬──────────┬────────┬───────────┬────────┐
# │ Date ┆ Open ┆ High ┆ Low ┆ … ┆ AdjClose ┆ Volume ┆ Dividends ┆ Splits │
# │ ---  ┆ ---  ┆ ---  ┆ --- ┆   ┆ ---      ┆ ---    ┆ ---       ┆ ---    │
# │ date ┆ f64  ┆ f64  ┆ f64 ┆   ┆ f64      ┆ f64    ┆ f64       ┆ f64    │
# ╞══════╪══════╪══════╪═════╪═══╪══════════╪════════╪═══════════╪════════╡
# └──────┴──────┴──────┴─────┴───┴──────────┴────────┴───────────┴────────┘

# %%
aQuarterly = aTick.financials_quarterly
rows_with_nulls = aQuarterly.filter(
    pl.any_horizontal(
        pl.all().is_null()
    )
)
rows_with_nulls.tail()
# Out:
# shape: (5, 16)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ fiscalDat ┆ reportedD ┆ reportedE ┆ estimated ┆ … ┆ totalCurr ┆ totalShar ┆ commonSto ┆ operatin │
# │ eEnding   ┆ ate       ┆ PS        ┆ EPS       ┆   ┆ entLiabil ┆ eholderEq ┆ ckSharesO ┆ gCashflo │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ities     ┆ uity      ┆ utstandin ┆ w        │
# │ date      ┆ date      ┆ f64       ┆ f64       ┆   ┆ ---       ┆ ---       ┆ g         ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ ---       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ f64       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2004-01-3 ┆ 2004-02-1 ┆ 0.21      ┆ 0.22      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆ 7         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2004-04-3 ┆ 2004-05-1 ┆ 0.24      ┆ 0.24      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 0         ┆ 7         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2004-07-3 ┆ 2004-08-1 ┆ 0.3       ┆ 0.28      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆ 2         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2004-10-3 ┆ 2004-11-1 ┆ 0.3       ┆ 0.31      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆ 1         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-10-3 ┆ 2024-11-2 ┆ 1.46      ┆ 1.41      ┆ … ┆ 1.8950e9  ┆ 5.8980e9  ┆ 2.91e8    ┆ 4.81e8   │
# │ 1         ┆ 5         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
aAnnually = aTick.financials_annually
rows_with_nulls = aAnnually.filter(
    pl.any_horizontal(
        pl.all().is_null()
    )
)
rows_with_nulls.tail()
# Out:
# shape: (5, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ fiscalDat ┆ reportedE ┆ grossProf ┆ totalReve ┆ … ┆ totalAsse ┆ totalCurr ┆ totalShar ┆ operatin │
# │ eEnding   ┆ PS        ┆ it        ┆ nue       ┆   ┆ ts        ┆ entLiabil ┆ eholderEq ┆ gCashflo │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ities     ┆ uity      ┆ w        │
# │ date      ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2000-10-3 ┆ 1.77      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2001-10-3 ┆ -0.22     ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2002-10-3 ┆ -1.4175   ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2003-10-3 ┆ -0.25     ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2004-10-3 ┆ 1.05      ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
financials_quarterly = CleanData.financial_fiscalDateIncongruence(fin)

financials_quarterly.tail(7)
# Out:
#     fiscalDateEnding reportedDate reportedEPS estimatedEPS surprise  \
# 96        2023-04-30   2023-05-24       0.109        0.092    0.017
# 97        2023-07-30   2023-08-23        0.27        0.207    0.063
# 98        2023-10-29   2023-11-21       0.402        0.336    0.066
# 99        2024-01-28   2024-02-21       0.516        0.461    0.055
# 100       2024-04-28   2024-05-22       0.612        0.559    0.053
# 101       2024-07-28   2024-08-28        0.68         0.63     0.05
# 102       2024-10-27   2024-11-20        0.81         0.74     0.07
#
#     surprisePercentage   reportTime reportedCurrency  grossProfit  \
# 96             18.4783  post-market              USD   4648000000
# 97             30.4348  post-market              USD   9462000000
# 98             19.6429  post-market              USD  13400000000
# 99             11.9306  post-market              USD  16791000000
# 100             9.4812  post-market              USD  20406000000
# 101             7.9365  post-market              USD  22574000000
# 102             9.4595  post-market              USD  26156000000
#
#     totalRevenue  ... depreciation depreciationAndAmortization  \
# 96    7192000000  ...         None                   181000000
# 97   13507000000  ...         None                   146000000
# 98   18120000000  ...         None                   144000000
# 99   22103000000  ...         None                   143000000
# 100  26044000000  ...         None                   143000000
# 101  30040000000  ...         None                   146000000
# 102  35082000000  ...         None                   149000000
#
#     incomeBeforeTax incomeTaxExpense interestAndDebtExpense  \
# 96       2209000000        166000000               66000000
# 97       6981000000        793000000               65000000
# 98      10523000000       1279000000               63000000
# 99      14106000000       1821000000               63000000
# 100     17279000000       2398000000               64000000
# 101     19214000000       2615000000               61000000
# 102     22316000000       3007000000               61000000
#
#     netIncomeFromContinuingOperations comprehensiveIncomeNetOfTax  \
# 96                         2043000000                  2036000000
# 97                         6188000000                  6187000000
# 98                         9242000000                  9206000000
# 99                        12285000000                 12400000000
# 100                       14881000000                 14745000000
# 101                       16599000000                 16764000000
# 102                       19309000000                 19356000000
#
#             ebit       ebitda    netIncome
# 96    2275000000   2456000000   2043000000
# 97    7046000000   7192000000   6188000000
# 98   10586000000  10730000000   9243000000
# 99   14169000000  14312000000  12285000000
# 100  17343000000  17486000000  14881000000
# 101  18642000000  18788000000  16599000000
# 102  21869000000  22018000000  19309000000
#
# [7 rows x 32 columns]

# %%
sectorDict = {}
for ticker, asset in assetspl.items():
    sectorDict[asset.sector] = asset.sector
    
print(sectorDict.keys())
# Out:
# dict_keys(['LIFE SCIENCES', 'TECHNOLOGY', 'MANUFACTURING', 'TRADE & SERVICES', 'REAL ESTATE & CONSTRUCTION', 'FINANCE', 'ENERGY & TRANSPORTATION'])

# %%
categories = [
            'other', 'industrials', 'healthcare', 'technology', 'utilities', 
            'financial-services', 'basic-materials', 'real-estate', 
            'consumer-defensive', 'energy', 'communication-services', 
            'consumer-cyclical'
]
